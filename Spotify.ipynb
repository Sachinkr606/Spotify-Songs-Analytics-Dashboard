# %%
import pandas as pd

# Load fully cleaned Spotify dataset
df = pd.read_excel("spotify_data_cleaned.xlsx")
df.head()

# %%
# Display singer columns: original vs primary_singer vs co_singers vs all_singers
df[['singer', 'primary_singer', 'co_singers', 'all_singers']].head(15)

# %%
# Display released_date alongside the extracted year column
df[['released_date', 'year']].head(10)

# %%
# Verify zero missing / blank values across all 24 columns
print("Total missing values:", df.isnull().sum().sum())
df.isnull().sum()

# %%
# Dataset Overview
df.info()

# %%
# Summary Statistics
df.describe()
